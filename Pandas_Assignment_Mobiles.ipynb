# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\prave\Downloads\cleaned_all_phones.csv")

# %%
datac=data.copy()

# %%
datac
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
datac.head()
# Out:
#        phone_name   brand           os  inches resolution  battery  \
# 0    Y6II Compact  Huawei  Android 5.1     5.0   720x1280     2200
# 1        K20 plus      LG  Android 7.0     5.3   720x1280     2700
# 2  P8 Lite (2017)  Huawei  Android 7.0     5.2  1080x1920     3000
# 3    Redmi Note 4  Xiaomi  Android 6.0     5.5  1080x1920     4100
# 4             P10  Huawei  Android 7.0     5.1  1080x1920     3200
#
#   battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# 0        Li-Po        2        2016-09-01      140.0  ...        False
# 1       Li-Ion        2        2016-12-01      140.0  ...         True
# 2       Li-Ion        4        2017-01-01      147.0  ...         True
# 3        Li-Po        4        2017-01-01      165.0  ...         True
# 4       Li-Ion        4        2017-02-01      145.0  ...         True
#
#    video_4K  video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# ...

# %%
datac.nunique()
# Out:
# phone_name           1496
# brand                  13
# os                     34
# inches                 99
# resolution             85
# battery               136
# battery_type            2
# ram(GB)                12
# announcement_date     665
# weight(g)             127
# storage(GB)             8
# video_720p              2
# video_1080p             2
# video_4K                2
# video_8K                2
# video_30fps             2
# video_60fps             2
# video_120fps            2
# video_240fps            2
# video_480fps            2
# video_960fps            2
# price(USD)            442
# dtype: int64

# %%
datac.head()
# Out:
#        phone_name   brand           os  inches resolution  battery  \
# 0    Y6II Compact  Huawei  Android 5.1     5.0   720x1280     2200
# 1        K20 plus      LG  Android 7.0     5.3   720x1280     2700
# 2  P8 Lite (2017)  Huawei  Android 7.0     5.2  1080x1920     3000
# 3    Redmi Note 4  Xiaomi  Android 6.0     5.5  1080x1920     4100
# 4             P10  Huawei  Android 7.0     5.1  1080x1920     3200
#
#   battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# 0        Li-Po        2        2016-09-01      140.0  ...        False
# 1       Li-Ion        2        2016-12-01      140.0  ...         True
# 2       Li-Ion        4        2017-01-01      147.0  ...         True
# 3        Li-Po        4        2017-01-01      165.0  ...         True
# 4       Li-Ion        4        2017-02-01      145.0  ...         True
#
#    video_4K  video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# ...

# %% [markdown]
# ### 1. How many unique mobile brands are there ?

# %%
datac["brand"].nunique()
# Out:
# 13

# %%
datac["brand"].unique()
# Out:
# array(['Huawei', 'LG', 'Xiaomi', 'Sony', 'Oppo', 'Samsung', 'Lenovo',
#        'Apple', 'Google', 'Honor', 'Realme', 'OnePlus', 'Vivo'],
#       dtype=object)

# %% [markdown]
# ### 2.What is the average RAM in all mobiles ?

# %%
datac["ram(GB)"].mean()
# Out:
# 6.6838624338624335

# %% [markdown]
# ### 3.Which phone is having the maximum battery capacity ?

# %%
datac.loc[datac["battery"]==datac["battery"].max(),["phone_name","brand","battery"]]
# Out:
#     phone_name  brand  battery
# 573         V6  Honor     7250

# %% [markdown]
# ### 4.Which phone is having the minimum battery capacity ?

# %%
datac.loc[datac["battery"]==datac["battery"].min(),["phone_name","brand","battery"]]
# Out:
#            phone_name  brand  battery
# 62           iPhone 8  Apple     1821
# 536  iPhone SE (2020)  Apple     1821

# %% [markdown]
# ### 5. What is the maximum battery capacity provided by Huawei Brand ?

# %%
x1=datac.loc[datac["brand"]=="Huawei"]

# %%
x1["battery"].max()
# Out:
# 7000

# %%
x1.loc[x1["battery"]==7000,["brand","battery"]]
# Out:
#        brand  battery
# 1448  Huawei     7000

# %% [markdown]
# ### 6. Which Phone brand has the minimum RAM ?

# %%
x1=datac["ram(GB)"].min()

# %%
x1
# Out:
# 1

# %%
x2=datac.loc[datac["ram(GB)"]==1]
x2
# Out:
#                 phone_name    brand                os  inches resolution  \
# 27               Y3 (2017)   Huawei       Android 6.0    5.00    480x854
# 28                      Z4  Samsung         Tizen 3.0    4.50    480x800
# 69        Galaxy J2 (2017)  Samsung       Android 7.0    4.70    540x960
# 133              Y3 (2018)   Huawei  Android 8.0 Oreo    5.00    480x854
# 182         Galaxy J2 Core  Samsung  Android 8.1 Oreo    5.00    540x960
# 230         Galaxy J4 Core  Samsung  Android 8.1 Oreo    6.00   720x1480
# 236         Y5 lite (2018)   Huawei  Android 8.1 Oreo    5.45   720x1440
# 244               Redmi Go   Xiaomi  Android 8.1 Oreo    5.00   720x1280
# 304         Galaxy A2 Core  Samsung  Android 8.0 Oreo    5.00    540x960
# 363             K20 (2019)       LG   Android 9.0 Pie    5.45    480x960
# 550  Galaxy J2 Core (2020)  Samsung  Android 8.1 Oreo    5.00    540x960
#
#      battery battery_type  ram(GB) announcement_date  weight(g)  ...  \
# ...

# %%
print(x2["brand"].unique() , "has the min RAM")
# Out:
# ['Huawei' 'Samsung' 'Xiaomi' 'LG'] has the min RAM

# %% [markdown]
# ### 7. Which is the oldest Phone announced and give their date of announcement ?

# %%
datac.head()
# Out:
#        phone_name   brand           os  inches resolution  battery  \
# 0    Y6II Compact  Huawei  Android 5.1     5.0   720x1280     2200
# 1        K20 plus      LG  Android 7.0     5.3   720x1280     2700
# 2  P8 Lite (2017)  Huawei  Android 7.0     5.2  1080x1920     3000
# 3    Redmi Note 4  Xiaomi  Android 6.0     5.5  1080x1920     4100
# 4             P10  Huawei  Android 7.0     5.1  1080x1920     3200
#
#   battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# 0        Li-Po        2        2016-09-01      140.0  ...        False
# 1       Li-Ion        2        2016-12-01      140.0  ...         True
# 2       Li-Ion        4        2017-01-01      147.0  ...         True
# 3        Li-Po        4        2017-01-01      165.0  ...         True
# 4       Li-Ion        4        2017-02-01      145.0  ...         True
#
#    video_4K  video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# ...

# %%
d1=datac["announcement_date"].min()
d1
# Out:
# '2016-09-01'

# %%
datac.loc[datac["announcement_date"]==d1,["phone_name","brand","announcement_date"]]
# Out:
#      phone_name   brand announcement_date
# 0  Y6II Compact  Huawei        2016-09-01

# %% [markdown]
# ### 8. How many phones has android 7.0 as there operating system ?

# %%
os=datac[datac["os"]=="Android 7.0"].value_counts("os")

# %%
os
# Out:
# os
# Android 7.0    33
# dtype: int64

# %% [markdown]
# ### 9. Which brand produced least number of phones ?

# %%
datac["brand"].value_counts()
# Out:
# Xiaomi     264
# Oppo       213
# Samsung    206
# Vivo       168
# Realme     157
# Huawei     137
# Honor      124
# LG          75
# OnePlus     47
# Lenovo      43
# Sony        37
# Apple       22
# Google      19
# Name: brand, dtype: int64

# %%
print("Google produced least no of phones ie 19")
# Out:
# Google produced least no of phones ie 19

# %% [markdown]
# ### 10.Give the phone and brand name of Costliest phone ?

# %%
datac["price(USD)"].max()
# Out:
# 2300.0

# %%
datac.loc[datac["price(USD)"]==2300.0,["phone_name","brand","price(USD)"]]
# Out:
#     phone_name   brand  price(USD)
# 777     P40 4G  Huawei      2300.0

# %% [markdown]
# ### 11.Give the phone and brand name of Cheapest phone ?

# %%
datac["price(USD)"].min()
# Out:
# 40.0

# %%
datac.loc[datac["price(USD)"]==40.0,["phone_name","brand","price(USD)"]]
# Out:
#     phone_name   brand  price(USD)
# 452        C2s  Realme        40.0

# %% [markdown]
# ### 12.How many phones supports 1)4k video 2)8k video 3)2k(1080p) video ?

# %% [markdown]
# ##### 1)4k video

# %%
a1=datac.loc[datac["video_4K"]==True]
a1
# Out:
#              phone_name    brand           os  inches resolution  battery  \
# 4                   P10   Huawei  Android 7.0    5.10  1080x1920     3200
# 7              P10 Plus   Huawei  Android 7.0    5.50  1440x2560     3750
# 11           Xperia XZs     Sony  Android 7.1    5.20  1080x1920     2900
# 12    Xperia XZ Premium     Sony  Android 7.1    5.46  3840x2160     3230
# 15              F3 Plus     Oppo    Android 6    6.00  1080x1920     4000
# ...                 ...      ...          ...     ...        ...      ...
# 1505    Redmi K60 Ultra   Xiaomi   Android 13    6.67  1220x2712     5000
# 1506          Ace 2 Pro  OnePlus   Android 13    6.74  1240x2772     5000
# 1509                GT5   Realme   Android 13    6.74  1240x2772     5240
# 1510           GT5 240W   Realme   Android 13    6.74  1240x2772     4600
# 1511   vivo iQOO Z7 Pro     Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
a1["phone_name"].count()
# Out:
# 801

# %% [markdown]
# ##### 2)8k video

# %%
a2=datac.loc[datac["video_8K"]==True]
a2
# Out:
#                phone_name    brand          os  inches resolution  battery  \
# 466         Galaxy S20 5G  Samsung  Android 10    6.20  1440x3200     4000
# 467        Galaxy S20+ 5G  Samsung  Android 10    6.70  1440x3200     4500
# 468      Galaxy S20 Ultra  Samsung  Android 10    6.90  1440x3200     5000
# 470   Galaxy S20 Ultra 5G  Samsung  Android 10    6.90  1440x3200     5000
# 471           Galaxy S20+  Samsung  Android 10    6.70  1440x3200     4500
# ...                   ...      ...         ...     ...        ...      ...
# 1447       vivo iQOO Neo8     Vivo  Android 13    6.78  1260x2800     5000
# 1476        vivo iQOO 11S     Vivo  Android 13    6.78  1440x3200     4700
# 1497       Galaxy Z Fold5  Samsung  Android 13    7.60  1812x2176     4400
# 1504           Mix Fold 3   Xiaomi  Android 13    8.03  1916x2160     4800
# 1505      Redmi K60 Ultra   Xiaomi  Android 13    6.67  1220x2712     5000
#
# ...

# %%
a2["phone_name"].count()
# Out:
# 86

# %% [markdown]
# ##### 2k(1080p) video

# %%
a3=datac.loc[datac["video_1080p"]==True]
a3
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# 5           Xperia XA1    Sony  Android 7.0    5.00   720x1280     2300
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
a3["phone_name"].count()
# Out:
# 1503
